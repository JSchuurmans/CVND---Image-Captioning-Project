# %% [markdown]
# # Computer Vision Nanodegree
#
# ## Project: Image Captioning
#
# ---
#
# In this notebook, you will train your CNN-RNN model.
#
# You are welcome and encouraged to try out many different architectures and hyperparameters when searching for a good model.
#
# This does have the potential to make the project quite messy!  Before submitting your project, make sure that you clean up:
# - the code you write in this notebook.  The notebook should describe how to train a single CNN-RNN architecture, corresponding to your final choice of hyperparameters.  You should structure the notebook so that the reviewer can replicate your results by running the code in this notebook.
# - the output of the code cell in **Step 2**.  The output should show the output obtained when training the model from scratch.
#
# This notebook **will be graded**.
#
# Feel free to use the links below to navigate the notebook:
# - [Step 1](#step1): Training Setup
# - [Step 2](#step2): Train your Model
# - [Step 3](#step3): (Optional) Validate your Model

# %% [markdown]
# <a id='step1'></a>
# ## Step 1: Training Setup
#
# In this step of the notebook, you will customize the training of your CNN-RNN model by specifying hyperparameters and setting other options that are important to the training procedure.  The values you set now will be used when training your model in **Step 2** below.
#
# You should only amend blocks of code that are preceded by a `TODO` statement.  **Any code blocks that are not preceded by a `TODO` statement should not be modified**.
#
# ### Task #1
#
# Begin by setting the following variables:
# - `batch_size` - the batch size of each training batch.  It is the number of image-caption pairs used to amend the model weights in each training step.
# - `vocab_threshold` - the minimum word count threshold.  Note that a larger threshold will result in a smaller vocabulary, whereas a smaller threshold will include rarer words and result in a larger vocabulary.
# - `vocab_from_file` - a Boolean that decides whether to load the vocabulary from file.
# - `embed_size` - the dimensionality of the image and word embeddings.
# - `hidden_size` - the number of features in the hidden state of the RNN decoder.
# - `num_epochs` - the number of epochs to train the model.  We recommend that you set `num_epochs=3`, but feel free to increase or decrease this number as you wish.  [This paper](https://arxiv.org/pdf/1502.03044.pdf) trained a captioning model on a single state-of-the-art GPU for 3 days, but you'll soon see that you can get reasonable results in a matter of a few hours!  (_But of course, if you want your model to compete with current research, you will have to train for much longer._)
# - `save_every` - determines how often to save the model weights.  We recommend that you set `save_every=1`, to save the model weights after each epoch.  This way, after the `i`th epoch, the encoder and decoder weights will be saved in the `models/` folder as `encoder-i.pkl` and `decoder-i.pkl`, respectively.
# - `print_every` - determines how often to print the batch loss to the Jupyter notebook while training.  Note that you **will not** observe a monotonic decrease in the loss function while training - this is perfectly fine and completely expected!  You are encouraged to keep this at its default value of `100` to avoid clogging the notebook, but feel free to change it.
# - `log_file` - the name of the text file containing - for every step - how the loss and perplexity evolved during training.
#
# If you're not sure where to begin to set some of the values above, you can peruse [this paper](https://arxiv.org/pdf/1502.03044.pdf) and [this paper](https://arxiv.org/pdf/1411.4555.pdf) for useful guidance!  **To avoid spending too long on this notebook**, you are encouraged to consult these suggested research papers to obtain a strong initial guess for which hyperparameters are likely to work best.  Then, train a single model, and proceed to the next notebook (**3_Inference.ipynb**).  If you are unhappy with your performance, you can return to this notebook to tweak the hyperparameters (and/or the architecture in **model.py**) and re-train your model.

# %% [markdown]
# ### Question 1
#
# **Question:** Describe your CNN-RNN architecture in detail.  With this architecture in mind, how did you select the values of the variables in Task 1?  If you consulted a research paper detailing a successful implementation of an image captioning model, please provide the reference.
#
# **Answer:**
# Encoder:
# - The CNN will be RESNET-50 or RESNET-101 with pretrained weights,
# - Linear (Fully connected) layer to create feature vector
#
# Decoder:
# - The RNN component will be an LSTM module.
# - ? Use of Word Embeddings to initialize LSTM output.
# - Linear (Fully connected) layer
# - Feature vector is concatenated with \<start\>-token -> first_word
# - Feature vector is concatenated with first_word-token -> second_word
#
# batch_size = 12 (see GPU capacity)
# vocab_threshold = 5 (default=5 from 1_Preliminaries)
# vocab_from_file = False (Initially False, after set threshold set to True)
#
# embed_size = 300 (Experiment)
# hidden_size = 150 (Experiment)
# num_epochs = 3 (default=3)
#
# save_every = 1 (default=1)
# print_every = 100 (default=100) -> check train and valid plots of loss

# %% [markdown]
# ### TODO
#
# - Attention
# - Dropout in encoder and decoder

# %% [markdown]
# ### (Optional) Task #2
#
# Note that we have provided a recommended image transform `transform_train` for pre-processing the training images, but you are welcome (and encouraged!) to modify it as you wish.  When modifying this transform, keep in mind that:
# - the images in the dataset have varying heights and widths, and
# - if using a pre-trained model, you must perform the corresponding appropriate normalization.
#
# ### Question 2
#
# **Question:** How did you select the transform in `transform_train`?  If you left the transform at its provided value, why do you think that it is a good choice for your CNN architecture?
#
# **Answer:**
# No adjustments have been made so far.

# %% [markdown]
# ### Task #3
#
# Next, you will specify a Python list containing the learnable parameters of the model.  For instance, if you decide to make all weights in the decoder trainable, but only want to train the weights in the embedding layer of the encoder, then you should set `params` to something like:
# ```
# params = list(decoder.parameters()) + list(encoder.embed.parameters())
# ```
#
# ### Question 3
#
# **Question:** How did you select the trainable parameters of your architecture?  Why do you think this is a good choice?
#
# **Answer:**

# %% [markdown]
# ### Task #4
#
# Finally, you will select an [optimizer](http://pytorch.org/docs/master/optim.html#torch.optim.Optimizer).
#
# ### Question 4
#
# **Question:** How did you select the optimizer used to train your model?
#
# **Answer:**
# Adam optimizer always works well for me :)

# %%
# !pip install nltk
import nltk
nltk.download('punkt')
# Out:
# Requirement already satisfied: nltk in /opt/conda/lib/python3.6/site-packages (3.2.5)
# Requirement already satisfied: six in /opt/conda/lib/python3.6/site-packages (from nltk) (1.11.0)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import torch
import torch.nn as nn
from torchvision import transforms
import sys
sys.path.append('/opt/cocoapi/PythonAPI')
from pycocotools.coco import COCO
from data_loader import get_loader
from model import EncoderCNN, DecoderRNN
import math
from torch import optim


## TODO #1: Select appropriate values for the Python variables below.
batch_size = 12          # batch size
vocab_threshold = 5        # minimum word count threshold
vocab_from_file = True    # if True, load existing vocab file
embed_size = 300           # dimensionality of image and word embeddings
hidden_size = 150          # number of features in hidden state of the RNN decoder
num_epochs = 3             # number of training epochs
save_every = 1             # determines frequency of saving model weights
print_every = 100          # determines window for printing average loss
log_file = 'training_log.txt'       # name of file with saved training loss and perplexity

# (Optional) TODO #2: Amend the image transform below.
transform_train = transforms.Compose([ 
    transforms.Resize(256),                          # smaller edge of image resized to 256
    transforms.RandomAffine(degrees=15, translate=(.1,.1), shear=(10,10)),
    transforms.RandomCrop(224),                      # get 224x224 crop from random location
    transforms.RandomHorizontalFlip(),               # horizontally flip image with probability=0.5
    transforms.ColorJitter(brightness=0.1, contrast=0.1, saturation=0.1, 
                           hue=0.1),  # randomly change the brightness, contrast and saturation of an image
    transforms.ToTensor(),                           # convert the PIL Image to a tensor
    transforms.Normalize((0.485, 0.456, 0.406),      # normalize image for pre-trained model
                         (0.229, 0.224, 0.225))])

# Build data loader.
data_loader = get_loader(transform=transform_train,
                         mode='train',
                         batch_size=batch_size,
                         vocab_threshold=vocab_threshold,
                         vocab_from_file=vocab_from_file)

# The size of the vocabulary.
vocab_size = len(data_loader.dataset.vocab)
# Out:
# Vocabulary successfully loaded from vocab.pkl file!
# loading annotations into memory...
# Done (t=1.06s)
# creating index...
#   0%|          | 775/414113 [00:00<01:55, 3590.09it/s]
# index created!
# Obtaining caption lengths...
# 100%|██████████| 414113/414113 [01:34<00:00, 4381.21it/s]

# %%
# !pip install pytorch-nlp

# from torchnlp.word_to_vector import GloVe

# def unk(tensor):
#     shape = tensor.shape
#     return torch.randn(shape[0], shape[1], dtype=torch.float)

# vectors = GloVe(name='6B', dim=300)

# %%
# models.py

import torch
import torch.nn as nn
import torchvision.models as models
import torch.nn.functional as F



class EncoderCNN(nn.Module):
    def __init__(self, embed_size):
        super(EncoderCNN, self).__init__()
        resnet = models.resnet50(pretrained=True)
        for param in resnet.parameters():
            param.requires_grad_(False)
        
        modules = list(resnet.children())[:-1]
        self.resnet = nn.Sequential(*modules)
        self.embed = nn.Linear(resnet.fc.in_features, embed_size)

    def forward(self, images):
        features = self.resnet(images)
        features = features.view(features.size(0), -1)
        features = self.embed(features)
        return features
    

class DecoderRNN(nn.Module):
    def __init__(self, embed_size, hidden_size, vocab_size, num_layers=1, pretrained_embeds=None, debug=False):
        super(DecoderRNN, self).__init__()
        
        self.hidden_size = hidden_size
        
        self.word_embeddings = nn.Embedding(vocab_size, embed_size)
        if pretrained_embeds is not None:
            # torch.from_numpy(pretrained_embeds)
            self.word_embeddings = self.word_embeddings.weight.data.copy_(pretrained_embeds)
            self.word_embeddings.weight.requires_grad = False
        
        self.lstm = nn.LSTM(embed_size, hidden_size, num_layers, batch_first=True)
        self.dec = nn.Linear(hidden_size, vocab_size)
        
        self.debug = debug
    
    def forward(self, features, captions):
        if self.debug:
            print('features: ', features.shape)
            print('captions: ', captions.shape)
        
        embeds = self.word_embeddings(captions[:,:-1])
        if self.debug:
            print('embeds: ', embeds.shape)
        
        features = features.unsqueeze(1)
        if self.debug:
            print('unsq feats: ', features.shape)
        
        inputs = (features, embeds)
        inputs = torch.cat(inputs,1)
        if self.debug:
            print('inputs: ', inputs.shape)
        
#         inputs = inputs.view(len(inputs), 1, -1)
#         print('inputs.view', inputs.shape)
        
        h_shape = (1, inputs.shape[0], self.hidden_size)
        if self.debug:
            print('h-shape: ', h_shape)
        
        hidden = (torch.randn(h_shape).cuda(), 
                  torch.randn(h_shape).cuda())  # clean out hidden state
        
        out, hidden = self.lstm(inputs, hidden)
        if self.debug:
            print('out: ', out.shape)
            print('hidden: ', hidden[0].shape)
        
        token_space = self.dec(out)
        if self.debug:
            print('token_space: ', token_space.shape)
        
#         token_scores = F.log_softmax(x, dim=1) # nn.CrossEntory takes care of this
#         if self.debug:
#             print('token_scores: ', token_scores.shape)
        
        return token_space

    def sample(self, inputs, states=None, max_len=20):
        " accepts pre-processed image tensor (inputs) and returns predicted sentence (list of tensor ids of length max_len) "
        output = []
        # clear hidden state
        h_shape = (1, inputs.shape[0], self.hidden_size)
        hidden = (torch.randn(h_shape).cuda(), torch.randn(h_shape).cuda())
        # loop until <end> token is sampled or maximum length is reached
#         out, hidden = self.lstm()
        for i in range(max_len):
            out, hidden = self.lstm(inputs, hidden)
            if self.debug:
                print('out: ', out.shape)
            
            x = self.dec(out)
            if self.debug:
                print('x: ', x.shape)
            
            values, tokens = torch.max(x, dim=-1)
            if self.debug:
                print('tokens: ',tokens)
            token = tokens.item()
            output.append(token)
            if token==1:
                break
            inputs = self.word_embeddings(token)
        return output

# %%
# pretrained word embedding matrix

# pretrained_embeds = torch.empty(vocab_size, embed_size, dtype=torch.float)
# idx2word = data_loader.dataset.vocab.idx2word
# word2idx = data_loader.dataset.vocab.word2idx
# for k,v in word2idx.items():
#     try:
#         pretrained_embeds[v] = vectors[k].numpy()
#     except:
#         print('key: ', k)
#         print('value: ', v)

# %%
from torch.optim.lr_scheduler import StepLR

# %%
# Initialize the encoder and decoder. 
encoder = EncoderCNN(embed_size)
decoder = DecoderRNN(embed_size, hidden_size, vocab_size)

# Move models to GPU if CUDA is available. 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
encoder.to(device)
decoder.to(device)

# Define the loss function. 
criterion = nn.CrossEntropyLoss().cuda() if torch.cuda.is_available() else nn.CrossEntropyLoss()

# TODO #3: Specify the learnable parameters of the model.
# train all parameters except resnet weights...
# list(filter(lambda p: p.requires_grad, decoder.parameters()))
params = list(decoder.parameters()) + list(encoder.embed.parameters()) 

# TODO #4: Define the optimizer.
lr1=0.001
# lr2=0.0001
optimizer = optim.Adam(params, lr=lr1)
scheduler = StepLR(optimizer, step_size=1, gamma=0.1)

# Set the total number of training steps per epoch.
total_step = math.ceil(len(data_loader.dataset.caption_lengths) / data_loader.batch_sampler.batch_size)

# %%
import os

encoder_file = 'encoder-2.pkl'
decoder_file = 'decoder-2.pkl'

encoder.load_state_dict(torch.load(os.path.join('./models', encoder_file)))
decoder.load_state_dict(torch.load(os.path.join('./models', decoder_file)))

# %% [markdown]
# <a id='step2'></a>
# ## Step 2: Train your Model
#
# Once you have executed the code cell in **Step 1**, the training procedure below should run without issue.
#
# It is completely fine to leave the code cell below as-is without modifications to train your model.  However, if you would like to modify the code used to train the model below, you must ensure that your changes are easily parsed by your reviewer.  In other words, make sure to provide appropriate comments to describe how your code works!
#
# You may find it useful to load saved weights to resume training.  In that case, note the names of the files containing the encoder and decoder weights that you'd like to load (`encoder_file` and `decoder_file`).  Then you can load the weights by using the lines below:
#
# ```python
# # Load pre-trained weights before resuming training.
# encoder.load_state_dict(torch.load(os.path.join('./models', encoder_file)))
# decoder.load_state_dict(torch.load(os.path.join('./models', decoder_file)))
# ```
#
# While trying out parameters, make sure to take extensive notes and record the settings that you used in your various training runs.  In particular, you don't want to encounter a situation where you've trained a model for several hours but can't remember what settings you used :).
#
# ### A Note on Tuning Hyperparameters
#
# To figure out how well your model is doing, you can look at how the training loss and perplexity evolve during training - and for the purposes of this project, you are encouraged to amend the hyperparameters based on this information.
#
# However, this will not tell you if your model is overfitting to the training data, and, unfortunately, overfitting is a problem that is commonly encountered when training image captioning models.
#
# For this project, you need not worry about overfitting. **This project does not have strict requirements regarding the performance of your model**, and you just need to demonstrate that your model has learned **_something_** when you generate captions on the test data.  For now, we strongly encourage you to train your model for the suggested 3 epochs without worrying about performance; then, you should immediately transition to the next notebook in the sequence (**3_Inference.ipynb**) to see how your model performs on the test data.  If your model needs to be changed, you can come back to this notebook, amend hyperparameters (if necessary), and re-train the model.
#
# That said, if you would like to go above and beyond in this project, you can read about some approaches to minimizing overfitting in section 4.3.1 of [this paper](http://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=7505636).  In the next (optional) step of this notebook, we provide some guidance for assessing the performance on the validation dataset.

# %%
import time
t = round(time.time())
log_file = 'training_log_'+str(t)+'.txt'

# %%
import torch.utils.data as data
import numpy as np
import os
import requests
import time

# Open the training log file.
f = open(log_file, 'w')

old_time = time.time()
response = requests.request("GET", 
                            "http://metadata.google.internal/computeMetadata/v1/instance/attributes/keep_alive_token", 
                            headers={"Metadata-Flavor":"Google"})

for epoch in range(1, num_epochs+1):
    
    for i_step in range(1, total_step+1):
        
        if time.time() - old_time > 60:
            old_time = time.time()
            requests.request("POST", 
                             "https://nebula.udacity.com/api/v1/remote/keep-alive", 
                             headers={'Authorization': "STAR " + response.text})
        
        # Randomly sample a caption length, and sample indices with that length.
        indices = data_loader.dataset.get_train_indices()
        # Create and assign a batch sampler to retrieve a batch with the sampled indices.
        new_sampler = data.sampler.SubsetRandomSampler(indices=indices)
        data_loader.batch_sampler.sampler = new_sampler
        
        # Obtain the batch.
        images, captions = next(iter(data_loader))

        # Move batch of images and captions to GPU if CUDA is available.
        images = images.to(device)
        captions = captions.to(device)
        
        # Zero the gradients.
        decoder.zero_grad()
        encoder.zero_grad()
        
        # Pass the inputs through the CNN-RNN model.
        features = encoder(images)
        outputs = decoder(features, captions)
        
        # Calculate the batch loss.
        loss = criterion(outputs.view(-1, vocab_size), captions.view(-1))
        
        # Backward pass.
        loss.backward()
        
        # Update the parameters in the optimizer.
        optimizer.step()
        
        # Get training statistics.
        stats = 'Epoch [%d/%d], Step [%d/%d], Loss: %.4f, Perplexity: %5.4f' % (epoch, num_epochs, i_step, total_step, loss.item(), np.exp(loss.item()))
        
        # Print training statistics (on same line).
        print('\r' + stats, end="")
        sys.stdout.flush()
        
        # Print training statistics to file.
        f.write(stats + '\n')
        f.flush()
        
        # Print training statistics (on different line).
        if i_step % print_every == 0:
            print('\r' + stats)
        
        if epoch == 3 and i_step % 5000 == 0:
            torch.save(decoder.state_dict(), os.path.join('./models', 'decoder-%d-%d.pkl' % epoch, i_step))
            torch.save(encoder.state_dict(), os.path.join('./models', 'encoder-%d-%d.pkl' % epoch, i_step))
    # Save the weights.
    if epoch % save_every == 0:
        torch.save(decoder.state_dict(), os.path.join('./models', 'decoder-%d.pkl' % epoch))
        torch.save(encoder.state_dict(), os.path.join('./models', 'encoder-%d.pkl' % epoch))
    
    scheduler.step()
        
# Close the training log file.
f.close()
# Out:
# Epoch [1/3], Step [100/34510], Loss: 4.4290, Perplexity: 83.84685
# Epoch [1/3], Step [200/34510], Loss: 3.9263, Perplexity: 50.72104
# Epoch [1/3], Step [300/34510], Loss: 4.2916, Perplexity: 73.08028
# Epoch [1/3], Step [400/34510], Loss: 3.8402, Perplexity: 46.53687
# Epoch [1/3], Step [500/34510], Loss: 3.2190, Perplexity: 25.00355
# Epoch [1/3], Step [600/34510], Loss: 3.6855, Perplexity: 39.86434
# Epoch [1/3], Step [700/34510], Loss: 3.8335, Perplexity: 46.2248
# Epoch [1/3], Step [800/34510], Loss: 3.3816, Perplexity: 29.41856
# Epoch [1/3], Step [900/34510], Loss: 3.3022, Perplexity: 27.17349
# Epoch [1/3], Step [1000/34510], Loss: 3.3500, Perplexity: 28.5023
# Epoch [1/3], Step [1100/34510], Loss: 3.3523, Perplexity: 28.5678
# Epoch [1/3], Step [1200/34510], Loss: 3.8061, Perplexity: 44.97341
# Epoch [1/3], Step [1300/34510], Loss: 2.7729, Perplexity: 16.0056
# Epoch [1/3], Step [1400/34510], Loss: 3.1236, Perplexity: 22.7275
# Epoch [1/3], Step [1500/34510], Loss: 3.8270, Perplexity: 45.9226
# Epoch [1/3], Step [1600/34510], Loss: 3.2072, Perplexity: 24.7090
# Epoch [1/3], Step [1700/34510], Loss: 3.5900, Perplexity: 36.2327
# Epoch [1/3], Step [1800/34510], Loss: 3.1924, Perplexity: 24.3461
# Epoch [1/3], Step [1900/34510], Loss: 2.9285, Perplexity: 18.6988
# Epoch [1/3], Step [2000/34510], Loss: 2.8325, Perplexity: 16.9885
# Epoch [1/3], Step [2100/34510], Loss: 3.2019, Perplexity: 24.5802
# Epoch [1/3], Step [2200/34510], Loss: 3.1623, Perplexity: 23.6254
# Epoch [1/3], Step [2300/34510], Loss: 3.2890, Perplexity: 26.8162
# Epoch [1/3], Step [2400/34510], Loss: 3.4234, Perplexity: 30.6729
# Epoch [1/3], Step [2500/34510], Loss: 2.9479, Perplexity: 19.0663
# Epoch [1/3], Step [2600/34510], Loss: 3.1597, Perplexity: 23.5629
# Epoch [1/3], Step [2700/34510], Loss: 3.5779, Perplexity: 35.7989
# Epoch [1/3], Step [2800/34510], Loss: 3.8693, Perplexity: 47.9107
# Epoch [1/3], Step [2900/34510], Loss: 3.0597, Perplexity: 21.3206
# Epoch [1/3], Step [3000/34510], Loss: 3.1993, Perplexity: 24.5152
# Epoch [1/3], Step [3100/34510], Loss: 2.9164, Perplexity: 18.4747
# Epoch [1/3], Step [3200/34510], Loss: 3.5940, Perplexity: 36.3786
# Epoch [1/3], Step [3300/34510], Loss: 3.0930, Perplexity: 22.0425
# Epoch [1/3], Step [3400/34510], Loss: 3.5273, Perplexity: 34.03258
# Epoch [1/3], Step [3500/34510], Loss: 3.3163, Perplexity: 27.5573
# Epoch [1/3], Step [3600/34510], Loss: 2.8403, Perplexity: 17.1211
# Epoch [1/3], Step [3700/34510], Loss: 3.0380, Perplexity: 20.8629
# Epoch [1/3], Step [3800/34510], Loss: 2.6901, Perplexity: 14.7336
# Epoch [1/3], Step [3900/34510], Loss: 3.2416, Perplexity: 25.5755
# Epoch [1/3], Step [4000/34510], Loss: 2.7582, Perplexity: 15.7707
# Epoch [1/3], Step [4100/34510], Loss: 2.7839, Perplexity: 16.1825
# Epoch [1/3], Step [4200/34510], Loss: 3.1884, Perplexity: 24.2489
# Epoch [1/3], Step [4300/34510], Loss: 2.8886, Perplexity: 17.9687
# Epoch [1/3], Step [4400/34510], Loss: 2.7748, Perplexity: 16.0361
# Epoch [1/3], Step [4500/34510], Loss: 2.8505, Perplexity: 17.2963
# Epoch [1/3], Step [4600/34510], Loss: 2.4671, Perplexity: 11.7883
# Epoch [1/3], Step [4700/34510], Loss: 3.2031, Perplexity: 24.6093
# Epoch [1/3], Step [4800/34510], Loss: 2.3431, Perplexity: 10.4134
# Epoch [1/3], Step [4900/34510], Loss: 2.8807, Perplexity: 17.8272
# Epoch [1/3], Step [5000/34510], Loss: 2.6516, Perplexity: 14.1766
# Epoch [1/3], Step [5100/34510], Loss: 3.1582, Perplexity: 23.5275
# Epoch [1/3], Step [5200/34510], Loss: 3.0510, Perplexity: 21.1371
# Epoch [1/3], Step [5300/34510], Loss: 2.5638, Perplexity: 12.9844
# Epoch [1/3], Step [5400/34510], Loss: 2.5095, Perplexity: 12.2993
# Epoch [1/3], Step [5500/34510], Loss: 2.4995, Perplexity: 12.1767
# Epoch [1/3], Step [5600/34510], Loss: 2.4830, Perplexity: 11.9776
# Epoch [1/3], Step [5700/34510], Loss: 2.7238, Perplexity: 15.23885
# Epoch [1/3], Step [5800/34510], Loss: 2.6328, Perplexity: 13.9127
# Epoch [1/3], Step [5900/34510], Loss: 2.9264, Perplexity: 18.6603
# Epoch [1/3], Step [6000/34510], Loss: 2.4029, Perplexity: 11.0548
# Epoch [1/3], Step [6100/34510], Loss: 2.9024, Perplexity: 18.21759
# Epoch [1/3], Step [6200/34510], Loss: 2.2043, Perplexity: 9.06414
# Epoch [1/3], Step [6300/34510], Loss: 3.3813, Perplexity: 29.4102
# Epoch [1/3], Step [6400/34510], Loss: 3.3624, Perplexity: 28.8580
# Epoch [1/3], Step [6500/34510], Loss: 2.3922, Perplexity: 10.9380
# Epoch [1/3], Step [6600/34510], Loss: 2.6363, Perplexity: 13.9614
# Epoch [1/3], Step [6700/34510], Loss: 2.5974, Perplexity: 13.4282
# Epoch [1/3], Step [6800/34510], Loss: 2.2781, Perplexity: 9.75816
# Epoch [1/3], Step [6900/34510], Loss: 2.8012, Perplexity: 16.4646
# Epoch [1/3], Step [7000/34510], Loss: 2.5124, Perplexity: 12.3339
# Epoch [1/3], Step [7100/34510], Loss: 2.5615, Perplexity: 12.9547
# Epoch [1/3], Step [7200/34510], Loss: 2.7617, Perplexity: 15.8268
# Epoch [1/3], Step [7300/34510], Loss: 3.1057, Perplexity: 22.3244
# Epoch [1/3], Step [7400/34510], Loss: 2.2089, Perplexity: 9.10548
# Epoch [1/3], Step [7500/34510], Loss: 2.9350, Perplexity: 18.8214
# Epoch [1/3], Step [7600/34510], Loss: 3.1255, Perplexity: 22.7719
# Epoch [1/3], Step [7700/34510], Loss: 3.0920, Perplexity: 22.0203
# Epoch [1/3], Step [7800/34510], Loss: 2.7871, Perplexity: 16.2332
# Epoch [1/3], Step [7900/34510], Loss: 3.5153, Perplexity: 33.6259
# Epoch [1/3], Step [8000/34510], Loss: 2.7622, Perplexity: 15.8339
# Epoch [1/3], Step [8100/34510], Loss: 2.8743, Perplexity: 17.7135
# Epoch [1/3], Step [8200/34510], Loss: 2.7085, Perplexity: 15.0075
# Epoch [1/3], Step [8300/34510], Loss: 2.5992, Perplexity: 13.4526
# Epoch [1/3], Step [8400/34510], Loss: 2.9532, Perplexity: 19.1668
# Epoch [1/3], Step [8500/34510], Loss: 2.7108, Perplexity: 15.0408
# Epoch [1/3], Step [8600/34510], Loss: 2.0958, Perplexity: 8.13186
# Epoch [1/3], Step [8700/34510], Loss: 3.3129, Perplexity: 27.4655
# Epoch [1/3], Step [8800/34510], Loss: 2.4874, Perplexity: 12.0297
# Epoch [1/3], Step [8900/34510], Loss: 2.1944, Perplexity: 8.97505
# Epoch [1/3], Step [9000/34510], Loss: 2.9576, Perplexity: 19.2521
# Epoch [1/3], Step [9100/34510], Loss: 2.3745, Perplexity: 10.7453
# Epoch [1/3], Step [9200/34510], Loss: 3.0548, Perplexity: 21.2178
# Epoch [1/3], Step [9300/34510], Loss: 2.2540, Perplexity: 9.52581
# Epoch [1/3], Step [9400/34510], Loss: 2.2678, Perplexity: 9.65842
# Epoch [1/3], Step [9500/34510], Loss: 2.9438, Perplexity: 18.9887
# Epoch [1/3], Step [9600/34510], Loss: 3.1053, Perplexity: 22.3169
# Epoch [1/3], Step [9700/34510], Loss: 2.8324, Perplexity: 16.9857
# Epoch [1/3], Step [9800/34510], Loss: 2.3923, Perplexity: 10.9385
# Epoch [1/3], Step [9900/34510], Loss: 2.3919, Perplexity: 10.93457
# Epoch [1/3], Step [10000/34510], Loss: 2.4980, Perplexity: 12.1580
# Epoch [1/3], Step [10100/34510], Loss: 2.8247, Perplexity: 16.8562
# Epoch [1/3], Step [10200/34510], Loss: 2.2509, Perplexity: 9.49603
# Epoch [1/3], Step [10300/34510], Loss: 3.2468, Perplexity: 25.7076
# Epoch [1/3], Step [10400/34510], Loss: 2.7731, Perplexity: 16.0086
# Epoch [1/3], Step [10500/34510], Loss: 3.0421, Perplexity: 20.9497
# Epoch [1/3], Step [10600/34510], Loss: 2.6488, Perplexity: 14.1374
# Epoch [1/3], Step [10700/34510], Loss: 2.9914, Perplexity: 19.9130
# Epoch [1/3], Step [10800/34510], Loss: 2.3633, Perplexity: 10.6255
# Epoch [1/3], Step [10900/34510], Loss: 2.6657, Perplexity: 14.3782
# Epoch [1/3], Step [11000/34510], Loss: 2.1728, Perplexity: 8.78322
# Epoch [1/3], Step [11100/34510], Loss: 3.5490, Perplexity: 34.7791
# Epoch [1/3], Step [11200/34510], Loss: 3.2946, Perplexity: 26.9677
# Epoch [1/3], Step [11300/34510], Loss: 2.4591, Perplexity: 11.69392
# Epoch [1/3], Step [11400/34510], Loss: 2.4916, Perplexity: 12.0805
# Epoch [1/3], Step [11500/34510], Loss: 2.4187, Perplexity: 11.2314
# Epoch [1/3], Step [11600/34510], Loss: 2.7218, Perplexity: 15.2078
# Epoch [1/3], Step [11700/34510], Loss: 2.8550, Perplexity: 17.3746
# Epoch [1/3], Step [11800/34510], Loss: 2.5004, Perplexity: 12.1869
# Epoch [1/3], Step [11900/34510], Loss: 3.5073, Perplexity: 33.3588
# Epoch [1/3], Step [12000/34510], Loss: 2.6741, Perplexity: 14.4995
# Epoch [1/3], Step [12100/34510], Loss: 2.8234, Perplexity: 16.8343
# Epoch [1/3], Step [12200/34510], Loss: 2.4132, Perplexity: 11.1695
# Epoch [1/3], Step [12300/34510], Loss: 2.3565, Perplexity: 10.5542
# Epoch [1/3], Step [12400/34510], Loss: 2.5049, Perplexity: 12.2421
# Epoch [1/3], Step [12500/34510], Loss: 2.5255, Perplexity: 12.4966
# Epoch [1/3], Step [12600/34510], Loss: 3.0887, Perplexity: 21.94908
# Epoch [1/3], Step [12700/34510], Loss: 2.8514, Perplexity: 17.3117
# Epoch [1/3], Step [12800/34510], Loss: 2.7317, Perplexity: 15.35979
# Epoch [1/3], Step [12900/34510], Loss: 2.4155, Perplexity: 11.1954
# Epoch [1/3], Step [13000/34510], Loss: 2.7391, Perplexity: 15.47285
# Epoch [1/3], Step [13100/34510], Loss: 2.5418, Perplexity: 12.7027
# Epoch [1/3], Step [13200/34510], Loss: 2.3700, Perplexity: 10.6970
# Epoch [1/3], Step [13300/34510], Loss: 3.0683, Perplexity: 21.5048
# Epoch [1/3], Step [13400/34510], Loss: 2.2546, Perplexity: 9.53195
# Epoch [1/3], Step [13500/34510], Loss: 2.4535, Perplexity: 11.6294
# Epoch [1/3], Step [13600/34510], Loss: 2.5405, Perplexity: 12.6856
# Epoch [1/3], Step [13700/34510], Loss: 3.0295, Perplexity: 20.6870
# Epoch [1/3], Step [13800/34510], Loss: 3.8018, Perplexity: 44.7815
# Epoch [1/3], Step [13900/34510], Loss: 2.5438, Perplexity: 12.7276
# Epoch [1/3], Step [14000/34510], Loss: 2.9826, Perplexity: 19.7397
# Epoch [1/3], Step [14100/34510], Loss: 2.6838, Perplexity: 14.6399
# Epoch [1/3], Step [14200/34510], Loss: 3.5606, Perplexity: 35.1834
# Epoch [1/3], Step [14300/34510], Loss: 2.5226, Perplexity: 12.4609
# Epoch [1/3], Step [14400/34510], Loss: 2.2954, Perplexity: 9.92872
# Epoch [1/3], Step [14500/34510], Loss: 3.1162, Perplexity: 22.5608
# Epoch [1/3], Step [14600/34510], Loss: 2.2575, Perplexity: 9.55915
# Epoch [1/3], Step [14700/34510], Loss: 2.4943, Perplexity: 12.1135
# Epoch [1/3], Step [14800/34510], Loss: 2.5770, Perplexity: 13.1577
# Epoch [1/3], Step [14900/34510], Loss: 2.7332, Perplexity: 15.3814
# Epoch [1/3], Step [15000/34510], Loss: 3.4304, Perplexity: 30.8893
# Epoch [1/3], Step [15100/34510], Loss: 2.5626, Perplexity: 12.9698
# Epoch [1/3], Step [15200/34510], Loss: 2.4347, Perplexity: 11.4124
# Epoch [1/3], Step [15300/34510], Loss: 2.6818, Perplexity: 14.6119
# Epoch [1/3], Step [15400/34510], Loss: 2.9004, Perplexity: 18.1820
# Epoch [1/3], Step [15500/34510], Loss: 3.1274, Perplexity: 22.8154
# Epoch [1/3], Step [15600/34510], Loss: 2.5763, Perplexity: 13.1488
# Epoch [1/3], Step [15700/34510], Loss: 2.8968, Perplexity: 18.1164
# Epoch [1/3], Step [15800/34510], Loss: 2.7198, Perplexity: 15.17706
# Epoch [1/3], Step [15900/34510], Loss: 2.7687, Perplexity: 15.9372
# Epoch [1/3], Step [16000/34510], Loss: 2.3118, Perplexity: 10.0923
# Epoch [1/3], Step [16100/34510], Loss: 3.2235, Perplexity: 25.1159
# Epoch [1/3], Step [16200/34510], Loss: 2.7485, Perplexity: 15.6195
# Epoch [1/3], Step [16300/34510], Loss: 2.5226, Perplexity: 12.4613
# Epoch [1/3], Step [16400/34510], Loss: 2.8579, Perplexity: 17.4257
# Epoch [1/3], Step [16500/34510], Loss: 2.1688, Perplexity: 8.74804
# Epoch [1/3], Step [16600/34510], Loss: 2.5050, Perplexity: 12.2439
# Epoch [1/3], Step [16700/34510], Loss: 2.5088, Perplexity: 12.2907
# Epoch [1/3], Step [16800/34510], Loss: 1.8859, Perplexity: 6.592005
# Epoch [1/3], Step [16900/34510], Loss: 2.4563, Perplexity: 11.6611
# Epoch [1/3], Step [17000/34510], Loss: 2.4019, Perplexity: 11.0441
# Epoch [1/3], Step [17100/34510], Loss: 2.9555, Perplexity: 19.2122
# Epoch [1/3], Step [17200/34510], Loss: 2.9713, Perplexity: 19.5170
# Epoch [1/3], Step [17300/34510], Loss: 2.8907, Perplexity: 18.0065
# Epoch [1/3], Step [17400/34510], Loss: 2.7899, Perplexity: 16.2797
# Epoch [1/3], Step [17500/34510], Loss: 2.5424, Perplexity: 12.7097
# Epoch [1/3], Step [17600/34510], Loss: 2.8605, Perplexity: 17.4695
# Epoch [1/3], Step [17700/34510], Loss: 2.3998, Perplexity: 11.0205
# Epoch [1/3], Step [17800/34510], Loss: 2.5152, Perplexity: 12.3693
# Epoch [1/3], Step [17900/34510], Loss: 2.2983, Perplexity: 9.95713
# Epoch [1/3], Step [18000/34510], Loss: 3.4795, Perplexity: 32.4440
# Epoch [1/3], Step [18100/34510], Loss: 2.5030, Perplexity: 12.2188
# Epoch [1/3], Step [18200/34510], Loss: 2.8709, Perplexity: 17.6521
# Epoch [1/3], Step [18300/34510], Loss: 2.5601, Perplexity: 12.9375
# Epoch [1/3], Step [18400/34510], Loss: 2.7421, Perplexity: 15.51924
# Epoch [1/3], Step [18500/34510], Loss: 3.1241, Perplexity: 22.7398
# Epoch [1/3], Step [18600/34510], Loss: 2.6193, Perplexity: 13.7262
# Epoch [1/3], Step [18700/34510], Loss: 2.3801, Perplexity: 10.8061
# Epoch [1/3], Step [18800/34510], Loss: 2.7920, Perplexity: 16.3129
# Epoch [1/3], Step [18900/34510], Loss: 2.4327, Perplexity: 11.3897
# Epoch [1/3], Step [19000/34510], Loss: 2.9832, Perplexity: 19.7519
# Epoch [1/3], Step [19100/34510], Loss: 2.5465, Perplexity: 12.7621
# Epoch [1/3], Step [19200/34510], Loss: 2.7396, Perplexity: 15.4803
# Epoch [1/3], Step [19300/34510], Loss: 3.1794, Perplexity: 24.03235
# Epoch [1/3], Step [19400/34510], Loss: 2.2030, Perplexity: 9.05232
# Epoch [1/3], Step [19500/34510], Loss: 2.7787, Perplexity: 16.0983
# Epoch [1/3], Step [19600/34510], Loss: 2.6703, Perplexity: 14.4440
# Epoch [1/3], Step [19700/34510], Loss: 2.4275, Perplexity: 11.3308
# Epoch [1/3], Step [19800/34510], Loss: 2.7941, Perplexity: 16.3476
# Epoch [1/3], Step [19900/34510], Loss: 2.8221, Perplexity: 16.8122
# Epoch [1/3], Step [20000/34510], Loss: 2.8871, Perplexity: 17.9414
# Epoch [1/3], Step [20100/34510], Loss: 2.4488, Perplexity: 11.5744
# Epoch [1/3], Step [20200/34510], Loss: 2.4245, Perplexity: 11.2965
# Epoch [1/3], Step [20300/34510], Loss: 3.2506, Perplexity: 25.8053
# Epoch [1/3], Step [20400/34510], Loss: 2.3348, Perplexity: 10.3272
# Epoch [1/3], Step [20500/34510], Loss: 2.5069, Perplexity: 12.2669
# Epoch [1/3], Step [20600/34510], Loss: 2.5628, Perplexity: 12.9721
# Epoch [1/3], Step [20700/34510], Loss: 2.7488, Perplexity: 15.6231
# Epoch [1/3], Step [20800/34510], Loss: 2.2459, Perplexity: 9.44851
# Epoch [1/3], Step [20900/34510], Loss: 2.3399, Perplexity: 10.3801
# Epoch [1/3], Step [21000/34510], Loss: 2.4738, Perplexity: 11.8678
# Epoch [1/3], Step [21100/34510], Loss: 2.5937, Perplexity: 13.3788
# Epoch [1/3], Step [21200/34510], Loss: 2.8908, Perplexity: 18.0079
# Epoch [1/3], Step [21300/34510], Loss: 2.7459, Perplexity: 15.5783
# Epoch [1/3], Step [21400/34510], Loss: 2.5222, Perplexity: 12.4557
# Epoch [1/3], Step [21500/34510], Loss: 2.2471, Perplexity: 9.460059
# Epoch [1/3], Step [21600/34510], Loss: 2.7022, Perplexity: 14.9130
# Epoch [1/3], Step [21700/34510], Loss: 2.4837, Perplexity: 11.9859
# Epoch [1/3], Step [21800/34510], Loss: 2.6076, Perplexity: 13.5662
# Epoch [1/3], Step [21900/34510], Loss: 2.6873, Perplexity: 14.6925
# Epoch [1/3], Step [22000/34510], Loss: 2.4720, Perplexity: 11.8459
# Epoch [1/3], Step [22100/34510], Loss: 2.4178, Perplexity: 11.2206
# Epoch [1/3], Step [22200/34510], Loss: 2.9586, Perplexity: 19.2708
# Epoch [1/3], Step [22300/34510], Loss: 2.5528, Perplexity: 12.8428
# Epoch [1/3], Step [22400/34510], Loss: 3.2747, Perplexity: 26.4359
# Epoch [1/3], Step [22500/34510], Loss: 2.3760, Perplexity: 10.7615
# Epoch [1/3], Step [22600/34510], Loss: 2.6793, Perplexity: 14.5743
# Epoch [1/3], Step [22700/34510], Loss: 2.5911, Perplexity: 13.3449
# Epoch [1/3], Step [22800/34510], Loss: 3.0995, Perplexity: 22.1858
# Epoch [1/3], Step [22900/34510], Loss: 2.3681, Perplexity: 10.6766
# Epoch [1/3], Step [23000/34510], Loss: 2.6817, Perplexity: 14.6095
# Epoch [1/3], Step [23100/34510], Loss: 2.3153, Perplexity: 10.1275
# Epoch [1/3], Step [23200/34510], Loss: 2.3947, Perplexity: 10.9653
# Epoch [1/3], Step [23300/34510], Loss: 2.3574, Perplexity: 10.5635
# Epoch [1/3], Step [23400/34510], Loss: 2.3786, Perplexity: 10.7895
# Epoch [1/3], Step [23500/34510], Loss: 2.4704, Perplexity: 11.8275
# Epoch [1/3], Step [23600/34510], Loss: 2.4202, Perplexity: 11.2475
# Epoch [1/3], Step [23700/34510], Loss: 2.3339, Perplexity: 10.3178
# Epoch [1/3], Step [23800/34510], Loss: 3.4084, Perplexity: 30.21548
# Epoch [1/3], Step [23900/34510], Loss: 2.3240, Perplexity: 10.2168
# Epoch [1/3], Step [24000/34510], Loss: 2.9114, Perplexity: 18.3834
# Epoch [1/3], Step [24100/34510], Loss: 2.5298, Perplexity: 12.5506
# Epoch [1/3], Step [24200/34510], Loss: 3.2590, Perplexity: 26.0236
# Epoch [1/3], Step [24300/34510], Loss: 2.0812, Perplexity: 8.01388
# Epoch [1/3], Step [24400/34510], Loss: 2.5604, Perplexity: 12.9413
# Epoch [1/3], Step [24500/34510], Loss: 2.7781, Perplexity: 16.08765
# Epoch [1/3], Step [24600/34510], Loss: 2.2720, Perplexity: 9.69891
# Epoch [1/3], Step [24700/34510], Loss: 2.9265, Perplexity: 18.6615
# Epoch [1/3], Step [24800/34510], Loss: 2.2241, Perplexity: 9.24503
# Epoch [1/3], Step [24900/34510], Loss: 2.5322, Perplexity: 12.5816
# Epoch [1/3], Step [25000/34510], Loss: 2.1348, Perplexity: 8.45527
# Epoch [1/3], Step [25100/34510], Loss: 2.7510, Perplexity: 15.6587
# Epoch [1/3], Step [25200/34510], Loss: 2.6624, Perplexity: 14.3303
# Epoch [1/3], Step [25300/34510], Loss: 2.2351, Perplexity: 9.34719
# Epoch [1/3], Step [25400/34510], Loss: 2.6625, Perplexity: 14.3324
# Epoch [1/3], Step [25500/34510], Loss: 2.6483, Perplexity: 14.1303
# Epoch [1/3], Step [25600/34510], Loss: 2.7344, Perplexity: 15.4011
# Epoch [1/3], Step [25700/34510], Loss: 2.7751, Perplexity: 16.0402
# Epoch [1/3], Step [25800/34510], Loss: 2.7546, Perplexity: 15.7146
# Epoch [1/3], Step [25900/34510], Loss: 2.4582, Perplexity: 11.6833
# Epoch [1/3], Step [26000/34510], Loss: 3.0343, Perplexity: 20.7861
# Epoch [1/3], Step [26100/34510], Loss: 2.4686, Perplexity: 11.8064
# Epoch [1/3], Step [26200/34510], Loss: 2.3318, Perplexity: 10.2962
# Epoch [1/3], Step [26300/34510], Loss: 2.6673, Perplexity: 14.4014
# Epoch [1/3], Step [26400/34510], Loss: 2.0516, Perplexity: 7.780798
# Epoch [1/3], Step [26500/34510], Loss: 2.1221, Perplexity: 8.34838
# Epoch [1/3], Step [26600/34510], Loss: 2.7115, Perplexity: 15.0518
# Epoch [1/3], Step [26700/34510], Loss: 2.6226, Perplexity: 13.7712
# Epoch [1/3], Step [26800/34510], Loss: 2.3716, Perplexity: 10.7144
# Epoch [1/3], Step [26900/34510], Loss: 2.5459, Perplexity: 12.7544
# Epoch [1/3], Step [27000/34510], Loss: 2.7173, Perplexity: 15.1395
# Epoch [1/3], Step [27100/34510], Loss: 2.5459, Perplexity: 12.7541
# Epoch [1/3], Step [27200/34510], Loss: 2.1699, Perplexity: 8.75710
# Epoch [1/3], Step [27300/34510], Loss: 2.4634, Perplexity: 11.7445
# Epoch [1/3], Step [27400/34510], Loss: 3.0424, Perplexity: 20.9552
# Epoch [1/3], Step [27500/34510], Loss: 2.2975, Perplexity: 9.94958
# Epoch [1/3], Step [27600/34510], Loss: 2.6688, Perplexity: 14.4226
# Epoch [1/3], Step [27700/34510], Loss: 2.7624, Perplexity: 15.8376
# Epoch [1/3], Step [27800/34510], Loss: 2.5324, Perplexity: 12.5836
# Epoch [1/3], Step [27900/34510], Loss: 3.0103, Perplexity: 20.2944
# Epoch [1/3], Step [28000/34510], Loss: 2.1817, Perplexity: 8.86109
# Epoch [1/3], Step [28100/34510], Loss: 2.4977, Perplexity: 12.15503
# Epoch [1/3], Step [28200/34510], Loss: 2.6174, Perplexity: 13.7006
# Epoch [1/3], Step [28300/34510], Loss: 2.4291, Perplexity: 11.3486
# Epoch [1/3], Step [28400/34510], Loss: 3.0420, Perplexity: 20.9475
# Epoch [1/3], Step [28500/34510], Loss: 2.8049, Perplexity: 16.5258
# Epoch [1/3], Step [28600/34510], Loss: 2.6818, Perplexity: 14.6112
# Epoch [1/3], Step [28700/34510], Loss: 2.1272, Perplexity: 8.39128
# Epoch [1/3], Step [28800/34510], Loss: 2.8502, Perplexity: 17.2905
# Epoch [1/3], Step [28900/34510], Loss: 2.5858, Perplexity: 13.2742
# Epoch [1/3], Step [29000/34510], Loss: 2.8094, Perplexity: 16.6007
# Epoch [1/3], Step [29100/34510], Loss: 2.8066, Perplexity: 16.5536
# Epoch [1/3], Step [29200/34510], Loss: 2.2467, Perplexity: 9.45624
# Epoch [1/3], Step [29300/34510], Loss: 2.2815, Perplexity: 9.79138
# Epoch [1/3], Step [29400/34510], Loss: 2.4480, Perplexity: 11.5656
# Epoch [1/3], Step [29500/34510], Loss: 2.6902, Perplexity: 14.7347
# Epoch [1/3], Step [29600/34510], Loss: 2.3788, Perplexity: 10.7916
# Epoch [1/3], Step [29700/34510], Loss: 2.7881, Perplexity: 16.2502
# Epoch [1/3], Step [29800/34510], Loss: 2.5476, Perplexity: 12.7766
# Epoch [1/3], Step [29900/34510], Loss: 2.7285, Perplexity: 15.3096
# Epoch [1/3], Step [30000/34510], Loss: 2.3117, Perplexity: 10.0912
# Epoch [1/3], Step [30100/34510], Loss: 2.5612, Perplexity: 12.9516
# Epoch [1/3], Step [30200/34510], Loss: 2.4927, Perplexity: 12.0941
# Epoch [1/3], Step [30300/34510], Loss: 2.4742, Perplexity: 11.8726
# Epoch [1/3], Step [30400/34510], Loss: 2.6977, Perplexity: 14.8451
# Epoch [1/3], Step [30500/34510], Loss: 2.7692, Perplexity: 15.9463
# Epoch [1/3], Step [30600/34510], Loss: 2.5965, Perplexity: 13.4168
# Epoch [1/3], Step [30700/34510], Loss: 2.2833, Perplexity: 9.80949
# Epoch [1/3], Step [30800/34510], Loss: 2.4467, Perplexity: 11.5507
# Epoch [1/3], Step [30900/34510], Loss: 4.4696, Perplexity: 87.31989
# Epoch [1/3], Step [31000/34510], Loss: 3.0413, Perplexity: 20.9332
# Epoch [1/3], Step [31100/34510], Loss: 2.3595, Perplexity: 10.5858
# Epoch [1/3], Step [31200/34510], Loss: 2.7356, Perplexity: 15.4189
# Epoch [1/3], Step [31300/34510], Loss: 1.9629, Perplexity: 7.11994
# Epoch [1/3], Step [31400/34510], Loss: 2.7546, Perplexity: 15.7150
# Epoch [1/3], Step [31500/34510], Loss: 2.2734, Perplexity: 9.71276
# Epoch [1/3], Step [31600/34510], Loss: 2.6996, Perplexity: 14.8737
# Epoch [1/3], Step [31700/34510], Loss: 2.6931, Perplexity: 14.7781
# Epoch [1/3], Step [31800/34510], Loss: 3.0691, Perplexity: 21.5231
# Epoch [1/3], Step [31900/34510], Loss: 2.8027, Perplexity: 16.4891
# Epoch [1/3], Step [32000/34510], Loss: 3.0509, Perplexity: 21.1352
# Epoch [1/3], Step [32100/34510], Loss: 2.6019, Perplexity: 13.4894
# Epoch [1/3], Step [32200/34510], Loss: 2.7659, Perplexity: 15.8928
# Epoch [1/3], Step [32300/34510], Loss: 2.6204, Perplexity: 13.7407
# Epoch [1/3], Step [32400/34510], Loss: 2.3089, Perplexity: 10.0638
# Epoch [1/3], Step [32500/34510], Loss: 2.4513, Perplexity: 11.6029
# Epoch [1/3], Step [32600/34510], Loss: 2.7288, Perplexity: 15.31435
# Epoch [1/3], Step [32700/34510], Loss: 2.9556, Perplexity: 19.2140
# Epoch [1/3], Step [32800/34510], Loss: 2.9300, Perplexity: 18.7282
# Epoch [1/3], Step [32900/34510], Loss: 2.6119, Perplexity: 13.6249
# Epoch [1/3], Step [33000/34510], Loss: 2.4312, Perplexity: 11.3726
# Epoch [1/3], Step [33100/34510], Loss: 2.2328, Perplexity: 9.32627
# Epoch [1/3], Step [33200/34510], Loss: 2.6892, Perplexity: 14.7205
# Epoch [1/3], Step [33300/34510], Loss: 2.5287, Perplexity: 12.5371
# Epoch [1/3], Step [33400/34510], Loss: 2.5992, Perplexity: 13.4528
# Epoch [1/3], Step [33500/34510], Loss: 3.1542, Perplexity: 23.4337
# Epoch [1/3], Step [33600/34510], Loss: 2.0968, Perplexity: 8.14029
# Epoch [1/3], Step [33700/34510], Loss: 2.5671, Perplexity: 13.0286
# Epoch [1/3], Step [33800/34510], Loss: 2.6951, Perplexity: 14.80743
# Epoch [1/3], Step [33900/34510], Loss: 2.2800, Perplexity: 9.77675
# Epoch [1/3], Step [34000/34510], Loss: 2.6857, Perplexity: 14.6684
# Epoch [1/3], Step [34100/34510], Loss: 2.5371, Perplexity: 12.6424
# Epoch [1/3], Step [34200/34510], Loss: 2.6538, Perplexity: 14.2074
# Epoch [1/3], Step [34300/34510], Loss: 2.2495, Perplexity: 9.48347
# Epoch [1/3], Step [34400/34510], Loss: 2.7100, Perplexity: 15.0287
# Epoch [1/3], Step [34500/34510], Loss: 2.5433, Perplexity: 12.7214
# Epoch [2/3], Step [100/34510], Loss: 2.7368, Perplexity: 15.437952
# Epoch [2/3], Step [200/34510], Loss: 2.6190, Perplexity: 13.7214
# Epoch [2/3], Step [300/34510], Loss: 2.6328, Perplexity: 13.9123
# Epoch [2/3], Step [400/34510], Loss: 2.5887, Perplexity: 13.3127
# Epoch [2/3], Step [500/34510], Loss: 2.6906, Perplexity: 14.7411
# Epoch [2/3], Step [600/34510], Loss: 2.1937, Perplexity: 8.96885
# Epoch [2/3], Step [700/34510], Loss: 2.5771, Perplexity: 13.1594
# Epoch [2/3], Step [800/34510], Loss: 2.6248, Perplexity: 13.8012
# Epoch [2/3], Step [900/34510], Loss: 2.6867, Perplexity: 14.6836
# Epoch [2/3], Step [1000/34510], Loss: 2.5988, Perplexity: 13.4473
# Epoch [2/3], Step [1100/34510], Loss: 2.0574, Perplexity: 7.82594
# Epoch [2/3], Step [1200/34510], Loss: 2.6438, Perplexity: 14.0668
# Epoch [2/3], Step [1300/34510], Loss: 2.2912, Perplexity: 9.88680
# Epoch [2/3], Step [1400/34510], Loss: 2.8977, Perplexity: 18.1324
# Epoch [2/3], Step [1500/34510], Loss: 2.7191, Perplexity: 15.1668
# Epoch [2/3], Step [1600/34510], Loss: 2.7569, Perplexity: 15.7516
# Epoch [2/3], Step [1700/34510], Loss: 3.2154, Perplexity: 24.9143
# Epoch [2/3], Step [1800/34510], Loss: 2.5320, Perplexity: 12.57906
# Epoch [2/3], Step [1900/34510], Loss: 2.3581, Perplexity: 10.5703
# Epoch [2/3], Step [2000/34510], Loss: 2.7497, Perplexity: 15.6379
# Epoch [2/3], Step [2100/34510], Loss: 2.2802, Perplexity: 9.77829
# Epoch [2/3], Step [2200/34510], Loss: 2.5504, Perplexity: 12.8125
# Epoch [2/3], Step [2300/34510], Loss: 2.8966, Perplexity: 18.1131
# Epoch [2/3], Step [2400/34510], Loss: 2.6022, Perplexity: 13.4937
# Epoch [2/3], Step [2500/34510], Loss: 2.3052, Perplexity: 10.0262
# Epoch [2/3], Step [2600/34510], Loss: 2.0289, Perplexity: 7.60601
# Epoch [2/3], Step [2700/34510], Loss: 3.0111, Perplexity: 20.3097
# Epoch [2/3], Step [2800/34510], Loss: 2.9183, Perplexity: 18.50900
# Epoch [2/3], Step [2900/34510], Loss: 2.3238, Perplexity: 10.2147
# Epoch [2/3], Step [3000/34510], Loss: 2.5457, Perplexity: 12.7523
# Epoch [2/3], Step [3100/34510], Loss: 2.8185, Perplexity: 16.7511
# Epoch [2/3], Step [3200/34510], Loss: 2.4890, Perplexity: 12.0487
# Epoch [2/3], Step [3300/34510], Loss: 2.2593, Perplexity: 9.57662
# Epoch [2/3], Step [3400/34510], Loss: 2.4729, Perplexity: 11.8563
# Epoch [2/3], Step [3500/34510], Loss: 2.4808, Perplexity: 11.9502
# Epoch [2/3], Step [3600/34510], Loss: 3.1691, Perplexity: 23.7856
# Epoch [2/3], Step [3700/34510], Loss: 2.7074, Perplexity: 14.9909
# Epoch [2/3], Step [3800/34510], Loss: 3.3080, Perplexity: 27.3294
# Epoch [2/3], Step [3900/34510], Loss: 2.8662, Perplexity: 17.5696
# Epoch [2/3], Step [4000/34510], Loss: 2.4626, Perplexity: 11.7350
# Epoch [2/3], Step [4100/34510], Loss: 2.6011, Perplexity: 13.4792
# Epoch [2/3], Step [4200/34510], Loss: 2.3556, Perplexity: 10.5446
# Epoch [2/3], Step [4300/34510], Loss: 2.4706, Perplexity: 11.8300
# Epoch [2/3], Step [4400/34510], Loss: 3.2189, Perplexity: 25.0006
# Epoch [2/3], Step [4500/34510], Loss: 2.2962, Perplexity: 9.93614
# Epoch [2/3], Step [4600/34510], Loss: 2.5198, Perplexity: 12.4266
# Epoch [2/3], Step [4700/34510], Loss: 2.7902, Perplexity: 16.2851
# Epoch [2/3], Step [4800/34510], Loss: 2.9729, Perplexity: 19.5483
# Epoch [2/3], Step [4900/34510], Loss: 2.7271, Perplexity: 15.2881
# Epoch [2/3], Step [5000/34510], Loss: 2.6051, Perplexity: 13.5330
# Epoch [2/3], Step [5100/34510], Loss: 2.2352, Perplexity: 9.34877
# Epoch [2/3], Step [5200/34510], Loss: 2.6784, Perplexity: 14.5618
# Epoch [2/3], Step [5300/34510], Loss: 2.5164, Perplexity: 12.3845
# Epoch [2/3], Step [5400/34510], Loss: 2.2024, Perplexity: 9.04669
# Epoch [2/3], Step [5500/34510], Loss: 2.4907, Perplexity: 12.0692
# Epoch [2/3], Step [5600/34510], Loss: 2.7494, Perplexity: 15.6339
# Epoch [2/3], Step [5700/34510], Loss: 2.4573, Perplexity: 11.6734
# Epoch [2/3], Step [5800/34510], Loss: 2.1570, Perplexity: 8.644814
# Epoch [2/3], Step [5900/34510], Loss: 2.4915, Perplexity: 12.0790
# Epoch [2/3], Step [6000/34510], Loss: 2.3915, Perplexity: 10.9297
# Epoch [2/3], Step [6100/34510], Loss: 2.9990, Perplexity: 20.0663
# Epoch [2/3], Step [6200/34510], Loss: 2.2321, Perplexity: 9.31941
# Epoch [2/3], Step [6300/34510], Loss: 3.1721, Perplexity: 23.8585
# Epoch [2/3], Step [6400/34510], Loss: 2.6473, Perplexity: 14.1161
# Epoch [2/3], Step [6500/34510], Loss: 2.8911, Perplexity: 18.0131
# Epoch [2/3], Step [6600/34510], Loss: 2.3675, Perplexity: 10.6711
# Epoch [2/3], Step [6700/34510], Loss: 2.4070, Perplexity: 11.1011
# Epoch [2/3], Step [6800/34510], Loss: 2.3425, Perplexity: 10.4068
# Epoch [2/3], Step [6900/34510], Loss: 2.8045, Perplexity: 16.5195
# Epoch [2/3], Step [7000/34510], Loss: 2.7047, Perplexity: 14.9501
# Epoch [2/3], Step [7100/34510], Loss: 2.7612, Perplexity: 15.8193
# Epoch [2/3], Step [7200/34510], Loss: 2.3342, Perplexity: 10.3216
# Epoch [2/3], Step [7300/34510], Loss: 2.7795, Perplexity: 16.1116
# Epoch [2/3], Step [7400/34510], Loss: 2.5591, Perplexity: 12.9246
# Epoch [2/3], Step [7500/34510], Loss: 2.6454, Perplexity: 14.0891
# Epoch [2/3], Step [7600/34510], Loss: 2.3221, Perplexity: 10.1974
# Epoch [2/3], Step [7700/34510], Loss: 2.5790, Perplexity: 13.1842
# Epoch [2/3], Step [7800/34510], Loss: 2.8991, Perplexity: 18.1576
# Epoch [2/3], Step [7900/34510], Loss: 2.5688, Perplexity: 13.0496
# Epoch [2/3], Step [8000/34510], Loss: 2.4795, Perplexity: 11.9354
# Epoch [2/3], Step [8100/34510], Loss: 2.3918, Perplexity: 10.9334
# Epoch [2/3], Step [8141/34510], Loss: 2.8685, Perplexity: 17.6105

# %% [markdown]
# <a id='step3'></a>
# ## Step 3: (Optional) Validate your Model
#
# To assess potential overfitting, one approach is to assess performance on a validation set.  If you decide to do this **optional** task, you are required to first complete all of the steps in the next notebook in the sequence (**3_Inference.ipynb**); as part of that notebook, you will write and test code (specifically, the `sample` method in the `DecoderRNN` class) that uses your RNN decoder to generate captions.  That code will prove incredibly useful here.
#
# If you decide to validate your model, please do not edit the data loader in **data_loader.py**.  Instead, create a new file named **data_loader_val.py** containing the code for obtaining the data loader for the validation data.  You can access:
# - the validation images at filepath `'/opt/cocoapi/images/train2014/'`, and
# - the validation image caption annotation file at filepath `'/opt/cocoapi/annotations/captions_val2014.json'`.
#
# The suggested approach to validating your model involves creating a json file such as [this one](https://github.com/cocodataset/cocoapi/blob/master/results/captions_val2014_fakecap_results.json) containing your model's predicted captions for the validation images.  Then, you can write your own script or use one that you [find online](https://github.com/tylin/coco-caption) to calculate the BLEU score of your model.  You can read more about the BLEU score, along with other evaluation metrics (such as TEOR and Cider) in section 4.1 of [this paper](https://arxiv.org/pdf/1411.4555.pdf).  For more information about how to use the annotation file, check out the [website](http://cocodataset.org/#download) for the COCO dataset.

# %%
# (Optional) TODO: Validate your model.
